# %% [markdown]
# <a href="https://colab.research.google.com/github/Souleymaneawe/Souleymaneawe/blob/main/Cours_intensif_sur_la_visualisation_interactive_des_donn%C3%A9es_avec_Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd

# %%
salary_df = pd.read_csv('employee_salaries.csv')
salary_df
# Out:
#       Years_of_Experience        Salary
# 0                1.000000   40000.00000
# 1                2.257942   65979.42119
# 2                2.450875   67253.57549
# 3                2.498713   67342.43510
# 4                2.613729   70532.20448
# ...                   ...           ...
# 1995            19.178575  421534.69100
# 1996            19.254499  430478.02650
# 1997            19.353369  438090.84540
# 1998            19.842520  482242.16080
# 1999            20.000000  500000.00000
#
# [2000 rows x 2 columns]

# %%
salary_df.head()
# Out:
#    Years_of_Experience       Salary
# 0             1.000000  40000.00000
# 1             2.257942  65979.42119
# 2             2.450875  67253.57549
# 3             2.498713  67342.43510
# 4             2.613729  70532.20448

# %%
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Years_of_Experience  2000 non-null   float64
#  1   Salary               2000 non-null   float64
# dtypes: float64(2)
# memory usage: 31.4 KB

# %%
fig = px.scatter(salary_df,x= 'Years_of_Experience', y= 'Salary')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
admission_df = pd.read_csv('university_admission.csv')
admission_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
fig1 = px.scatter(admission_df,x= 'GRE Score', y= 'Chance of Admit')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.scatter(admission_df,x= 'GRE Score', y= 'Chance of Admit', color ='University Rating')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.scatter(admission_df,x= 'GRE Score', y= 'Chance of Admit', color ='University Rating', size= 'SOP')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.scatter(admission_df,x= 'GRE Score', y= 'Chance of Admit', color ='University Rating', size= 'SOP', hover_data= ['LOR'])
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
admission_df['SOP'] = admission_df['SOP'] ** 2


fig3 = px.scatter(admission_df,x= 'GRE Score', y= 'Chance of Admit', color ='University Rating', size= 'SOP', hover_data= ['LOR'])
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crypto_df = pd.read_csv('crypto_prices.csv')
crypto_df
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
fig4 = px.line(crypto_df, x= 'Date', y= 'BTC-USD Price')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig4 = px.line(crypto_df, x= 'Date', y= 'LTC-USD Price')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crypto_df = pd.read_csv('crypto_prices.csv')
crypto_df
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
crypto_df.columns
# Out:
# Index(['Date', 'BTC-USD Price', 'ETH-USD Price', 'LTC-USD Price'], dtype='object')

# %%
fig = px.line()

for i in crypto_df.columns[1:]:
  fig.add_scatter(x= crypto_df['Date'], y= crypto_df[i], name = i)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crypto_df['BTC-USD Price'].max()
# Out:
# 61243.08594

# %%
crypto_df['BTC-USD Price'] == crypto_df['BTC-USD Price'].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2380    False
# 2381    False
# 2382    False
# 2383    False
# 2384    False
# Name: BTC-USD Price, Length: 2385, dtype: bool

# %%
crypto_df[crypto_df['Date'] == '3/13/2021']
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 2365  3/13/2021    61243.08594    1924.685425     226.578293

# %%
my_dict = {'allocation %': [20 ,20, 20, 20, 20]}
my_dict
# Out:
# {'allocation %': [20, 20, 20, 20, 20]}

# %%
my_dict = {'allocation %': [20, 20, 20, 20, 20]   } #remove one element to match the length of the index
crypto_df = pd.DataFrame(data = my_dict, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
crypto_df
# Out:
#      allocation %
# BTC            20
# ETH            20
# LTC            20
# XRP            20
# ADA            20

# %%
fig = px.pie(crypto_df, values = 'allocation %', names = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'], title = 'Crypto Allocation')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
my_dict = {'allocation %': [10 ,10, 10, 60, 10]  }
crypto_df = pd.DataFrame(data = my_dict, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
fig = px.pie(crypto_df, values = 'allocation %', names = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'], title = 'Crypto Allocation')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(crypto_df, values = 'allocation %', names = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'], hole=0.3, title = 'Crypto Allocation')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = px.data.gapminder()
data
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
data = pd.read_csv('gapminder.csv')
data
# Out:
#       Unnamed: 0      country continent  year  lifeExp       pop   gdpPercap  \
# 0              0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1              1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2              2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3              3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4              4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...          ...          ...       ...   ...      ...       ...         ...
# 1699        1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700        1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701        1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702        1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703        1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
#      iso_alpha  iso_num
# ...

# %%
canada_df = data[ data.country == 'Canada']
canada_df
# Out:
#      Unnamed: 0 country continent  year  lifeExp       pop    gdpPercap  \
# 240         240  Canada  Americas  1952   68.750  14785584  11367.16112
# 241         241  Canada  Americas  1957   69.960  17010154  12489.95006
# 242         242  Canada  Americas  1962   71.300  18985849  13462.48555
# 243         243  Canada  Americas  1967   72.130  20819767  16076.58803
# 244         244  Canada  Americas  1972   72.880  22284500  18970.57086
# 245         245  Canada  Americas  1977   74.210  23796400  22090.88306
# 246         246  Canada  Americas  1982   75.760  25201900  22898.79214
# 247         247  Canada  Americas  1987   76.860  26549700  26626.51503
# 248         248  Canada  Americas  1992   77.950  28523502  26342.88426
# 249         249  Canada  Americas  1997   78.610  30305843  28954.92589
# 250         250  Canada  Americas  2002   79.770  31902268  33328.96507
# 251         251  Canada  Americas  2007   80.653  33390141  36319.23501
#
#     iso_alpha  iso_num
# ...

# %%
fig = px.bar(canada_df, x= 'year', y= 'pop', labels= {'pop':'Population of Canada'}, height = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(canada_df, x='year', y='pop', color='lifeExp', hover_data=['gdpPercap'], labels={'pop': 'Population of Canada'}, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
senegal_df = data[ data.country == 'Senegal']
senegal_df
# Out:
#       Unnamed: 0  country continent  year  lifeExp       pop    gdpPercap  \
# 1320        1320  Senegal    Africa  1952   37.278   2755589  1450.356983
# 1321        1321  Senegal    Africa  1957   39.329   3054547  1567.653006
# 1322        1322  Senegal    Africa  1962   41.454   3430243  1654.988723
# 1323        1323  Senegal    Africa  1967   43.563   3965841  1612.404632
# 1324        1324  Senegal    Africa  1972   45.815   4588696  1597.712056
# 1325        1325  Senegal    Africa  1977   48.879   5260855  1561.769116
# 1326        1326  Senegal    Africa  1982   52.379   6147783  1518.479984
# 1327        1327  Senegal    Africa  1987   55.769   7171347  1441.720720
# 1328        1328  Senegal    Africa  1992   58.196   8307920  1367.899369
# 1329        1329  Senegal    Africa  1997   60.187   9535314  1392.368347
# 1330        1330  Senegal    Africa  2002   61.600  10870037  1519.635262
# 1331        1331  Senegal    Africa  2007   63.062  12267493  1712.472136
#
# ...

# %%
fig = px.bar(senegal_df, x= 'year', y= 'pop', labels= {'pop':'Population of Senegal'}, height = 500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(senegal_df, x='year', y='pop', color='lifeExp', hover_data=['gdpPercap'], labels={'pop': 'Population of Senegal'}, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
job_1 = {'Task':'Develop content', 'Start':'2020-10-10', 'Finish':'2021-01-01'}
job_1
# Out:
# {'Task': 'Develop content', 'Start': '2020-10-10', 'Finish': '2021-01-01'}

# %%
job_2 = {'Task':'Film Videos', 'Start':'2021-01-01', 'Finish':'2021-03-03'}
job_2
# Out:
# {'Task': 'Film Videos', 'Start': '2021-01-01', 'Finish': '2021-03-03'}

# %%
job_3 = {'Task':'Edit Videos', 'Start':'2021-03-03', 'Finish':'2021-04-04'}
job_3
# Out:
# {'Task': 'Edit Videos', 'Start': '2021-03-03', 'Finish': '2021-04-04'}

# %%
project = pd.DataFrame([job_1, job_2, job_3])
project
# Out:
#               Task       Start      Finish
# 0  Develop content  2020-10-10  2021-01-01
# 1      Film Videos  2021-01-01  2021-03-03
# 2      Edit Videos  2021-03-03  2021-04-04

# %%
fig = px.timeline(project, x_start = 'Start', x_end = 'Finish', y = 'Task')
fig.update_yaxes(autorange = 'reversed')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
job_4 = {'Task':'Send the Course for Approval', 'Start':'2021-04-04', 'Finish':'2021-04-05'}
job_4

project = pd.DataFrame([job_1, job_2, job_4])
project

fig = px.timeline(project, x_start = 'Start', x_end = 'Finish', y = 'Task')
fig.update_yaxes(autorange = 'reversed')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
restaurant_df = pd.read_csv('restaurant_mini.csv')
restaurant_df.dropna()
# Out:
#    Customer ID       Day Dining or Takeout  Age  Invoice
# 0            1  Saturday            Dining   23       45
# 1            2  Saturday            Dining   22       70
# 2            3    Sunday           Takeout   26       80
# 3            4    Sunday           Takeout   30      100

# %%
fig = px.sunburst(restaurant_df, path = ['Dining or Takeout', 'Day', 'Age'], values = 'Invoice')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
restaurant_mini_df = pd.read_csv('restaurant.csv')
restaurant_mini_df.dropna()
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
fig = px.sunburst(restaurant_mini_df, path = ['day', 'time', 'sex'], values = 'total_bill')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
